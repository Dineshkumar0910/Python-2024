# %%
name = input("Enter your name")
print(f"Hello,{name}")
# Out:
# Enter your name Selvan Dinesh Kumar
# Hello,Selvan Dinesh Kumar

# %%
n1 = int(input("Enter n1"))
n2 = int(input("Enter n2"))
print(f"The Sum is: {n1+n2}")
print(f"The Diff is: {n1-n2}")
print(f"The Product is: {n1*n2}")#
print(f"The Division is: {n1/n2}")
print(f"The Div is: {n1//n2}")
print(f"The Modulo is: {n1%n2}")
print(f"The Expo is: {n1**n2}")
# Out:
# Enter n1 7
# Enter n2 2
# The Sum is: 9
# The Diff is: 5
# The Product is: 14
# The Division is: 3.5
# The Div is: 3
# The Modulo is: 1
# The Expo is: 49

# %%
print(n1<n2,n1<=n2,n1>n2,n1>=n2)
print(n1==n2,n1!=n2)
# Out:
# False False True True
# False True

# %%
print(n1 is n2)
print(n1 is not n2)
# Out:
# False
# True

# %%
li = [3,6,21,56]
print(3 in li, 10 not in li)
# Out:
# True True

# %%
print(n1>n2 and n1>=n2)
print(n1>n2 and n1==n2)
# Out:
# True
# False

# %%
print(n1>n2 or n1>=n2)
print(n1>n2 or n1==n2)
# Out:
# True
# True

# %%
print(type(n1),type(n2))
n3 = 5.4
print(type(n3),type(name))
# Out:
# <class 'int'> <class 'int'>
# <class 'float'> <class 'str'>

# %%
#List#
print(li[0],li[1],li[-1])#indexing
li[0] = "Virat"#modify
print(li)
li.append('Rohit')
print(li)
li.insert(3,'Yuvraj')
print(li)
li.extend([4,6,1,34,'Raina'])
print(li)
# Out:
# Virat 6 Rohit
# ['Virat', 6, 21, 'Yuvraj', 56, 'Rohit', 'Rohit']
# ['Virat', 6, 21, 'Yuvraj', 56, 'Rohit', 'Rohit', 'Rohit']
# ['Virat', 6, 21, 'Yuvraj', 'Yuvraj', 56, 'Rohit', 'Rohit', 'Rohit']
# ['Virat', 6, 21, 'Yuvraj', 'Yuvraj', 56, 'Rohit', 'Rohit', 'Rohit', 4, 6, 1, 34, 'Raina']

# %%
li.remove("Rohit")
print(li)
# Out:
# ['Virat', 6, 21, 'Yuvraj', 'Yuvraj', 56, 'Rohit', 'Rohit', 4, 6, 1, 34, 'Raina']

# %%
li.pop()
print(li)
# Out:
# ['Virat', 6, 21, 'Yuvraj', 'Yuvraj', 56, 'Rohit', 'Rohit', 4, 6, 1, 34]

# %%
li.pop(6)
print(li)
# Out:
# ['Virat', 6, 21, 'Yuvraj', 'Yuvraj', 56, 'Rohit', 4, 6, 1, 34]

# %%
print(li[0:4])
print(li[-6:-1])
# Out:
# ['Virat', 6, 21, 'Yuvraj']
# [56, 'Rohit', 4, 6, 1]

# %%
li2 = ['Love','Jack','Rose','Titanic']
upper = [i.upper() for i in li2]
print(upper)
# Out:
# ['LOVE', 'JACK', 'ROSE', 'TITANIC']

# %%
li2.sort()
print(li2)
# Out:
# ['Jack', 'Love', 'Rose', 'Titanic']

# %%
li2.reverse()
print(li2)
# Out:
# ['Titanic', 'Rose', 'Love', 'Jack']

# %%
for x in li2:
    print(x)
# Out:
# Titanic
# Rose
# Love
# Jack

# %%
li2.count('Rose')
# Out:
# 1

# %%
#Tuple
tu1 = (2,5,3,7,2)
print(tu1,type(tu1))
# Out:
# (2, 5, 3, 7, 2) <class 'tuple'>

# %%
print(tu1[0],tu1[2])
# Out:
# 2 3

# %%
tu2 = (100,)
print(type(tu2))
# Out:
# <class 'tuple'>

# %%
q,w,e,r,t = tu1
print(q)
# Out:
# 2

# %%
a,*b,c = tu1
print(a)
print(b)
print(c)
# Out:
# 2
# [5, 3, 7]
# 2

# %%
print(name[0])
print(name[0:5])
# Out:
# S
# Selva

# %%
print(name.upper(),name.lower())
print(len(name))
# Out:
# SELVAN DINESH KUMAR selvan dinesh kumar
# 19

# %%
name2="     Python,v12"
print(name2.strip())
# Out:
# Python,v12

# %%
print(name2.replace("v12","version:12"))
# Out:
#      Python,version:12

# %%
li3 = name.split()
print(li3)
# Out:
# ['Selvan', 'Dinesh', 'Kumar']

# %%
join = "".join(li3)
print(join)
# Out:
# SelvanDineshKumar

# %%
'''Innovative Problem: "Mixed Data Unscrambler"

You are given a mixed list of tuples, strings, and lists, where each tuple contains a string and an integer, each string is a word, and each list contains a set of characters. Your task is to unscramble the data and return a new list with the following format:

Each tuple is converted into a string with the format "word:integer"
Each string is converted into a list of characters
Each list of characters is converted into a string with the characters in sorted order

python
unscrambled_data = [
    "hello:1",
    ["w", "o", "r", "l", "d"],
    "cde",
    "foo:2",
    ["a", "b", "r"],
    "bar",
    "baz:3",
    ["q", "u", "x"],
    "qux"
]

python
mixed_data = [
    ("hello", 1),
    "world",
    ["d", "e", "c"],
    ("foo", 2),
    "bar",
    ["b", "a", "r"],
    ("baz", 3),
    "qux",
    ["x", "u", "q"]
]'''
# Out:
#   Cell In[64], line 1
#     Innovative Problem: "Mixed Data Unscrambler"
#                ^
# SyntaxError: invalid syntax
